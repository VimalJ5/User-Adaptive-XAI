# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv(r"C:\Users\vimal\OneDrive\Documents\Uni\BTP\User-Adaptive-XAI\Medical-Abstracts-TC-Corpus\medical_tc_test.csv")

# %%
dataset.head()
# Out:
#    condition_label                                   medical_abstract
# 0                3  Obstructive sleep apnea following topical orop...
# 1                5  Neutrophil function and pyogenic infections in...
# 2                5  A phase II study of combined methotrexate and ...
# 3                1  Flow cytometric DNA analysis of parathyroid tu...
# 4                4  Paraneoplastic vasculitic neuropathy: a treata...

# %%
extracted_data = dataset["medical_abstract"].tolist()
print(len(extracted_data))

sampled_extracted_data = np.random.choice(extracted_data, size=500, replace=False).tolist()

with open("test_data.txt", "w", encoding="utf-8") as f:
    f.write("\n".join(sampled_extracted_data))

print(f"Saved {len(sampled_extracted_data)} items to test_data.txt")
# Out:
# 2888
# Saved 500 items to test_data.txt
