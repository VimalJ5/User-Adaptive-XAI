# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
result_path = "n_10"

# file_base = "_normal_lime.csv"
# names = ["beginner","expert"]

beg_file = pd.read_csv(f"{result_path}/beginner_normal_lime.csv")
expert_file = pd.read_csv(f"{result_path}/expert_normal_lime.csv")

# %%
beg_file.columns
# Out:
# Index(['input_index', 'experiment_tag', 'xai_method', 'user_category',
#        'ablation_mode', 'constrained_decoding', 'lambda', 'ner_merging',
#        'predicted_class', 'confidence', 'text_snippet', 'explanation',
#        'lime_coverage', 'ontology_hit_rate', 'flesch_reading_ease',
#        'flesch_kincaid_grade', 'smog_index'],
#       dtype='object')

# %%
beg_fre = beg_file['flesch_reading_ease'].mean()
expert_fre = expert_file['flesch_reading_ease'].mean()

beg_fkgl= beg_file['flesch_kincaid_grade'].mean()
expert_fkgl = expert_file['flesch_kincaid_grade'].mean()

print("Beginner FRE: ",beg_fre, " || ", "Beginner FKGL: ", beg_fkgl)
print("Expert FRE: ",expert_fre," || ", "Expert FKGL: ", expert_fkgl)
# Out:
# Beginner FRE:  73.59128609898048  ||  Beginner FKGL:  6.99405805324773
# Expert FRE:  23.058078318379746  ||  Expert FKGL:  16.064251763315045
